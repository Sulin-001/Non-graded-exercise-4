# %% [markdown]
# Write a simple program for a card Role-Playing Game. Try to use only the concepts you have learned so far in the lectures.
#
# REQUIREMENTS:
#
# 1. Following are the different cards, with their characteristics, available to the player
#
# Name: Diablo
# Health: 100
# Attack: 90
# Defense: 60
#
# Name: Medusa
# Health: 100
# Attack: 70
# Defense: 70
#
# Name: Jester
# Health: 120
# Attack: 60
# Defense: 90
#
# Name: Troll
# Health: 150
# Attack: 40
# Defense: 94
#
# Name: Specter
# Health: 100
# Attack: 70
# Defense: 70
#
# Name: Mist
# Health: 100
# Attack: 75
# Defense: 65
#
# Name: Savage
# Health: 100
# Attack: 90
# Defense: 50
#
# Name: Marauder
# Health: 100
# Attack: 85
# Defense: 50
#
# Name: Wimp
# Health: 110
# Attack: 40
# Defense: 85
#
# Name: Sorcerer
# Health: 100
# Attack: 70
# Defense: 55
#
# 2. Store the above card details using a suitable data structure like list, tuple, dictionary, or any combination of these
# 3. From these cards, assign a random deck of 5 cards to both the player and the computer (opponent).
#     3.1. This should happen whenever a new game begins
# 4. Keep the game running for as long as there are cards in the player's deck or for as long as there are cards in the opponent's deck
#     4.1. Show all the cards that the player has in their deck
#     4.2. Assign a random card to the opponent, and show that to the player, along with the details of that card. Only the details of this random card must be shown.
#     4.3. Ask the player to pick a card from their own deck to fight the opponent's card.
#     4.4. If the attack value of the player's card is more than the health of opponent's card, then the player wins this round.
#     4.5. Otherwise, the player's card will fight with the opponent's card.
#         4.5.1. Calculate the damage the player's card does to the opponent's card. This calculation should take care of the fact that the opponent's card will first defend the attack using its 'Defense' value. And if there is no defense value, only then will the player's attack value will affect the opponent card's health.
#
#         e.g.,
#         Player card
#
#         Name: Wimp
#         Health: 110
#         Attack: 40
#         Defense: 85
#
#
#         Opponent card
#
#         Name: Sorcerer
#         Health: 100
#         Attack: 70
#         Defense: 55
#
#         If the Wimp attacks Sorcerer, first, it will only affect Sorcerer's 'Defense' value. Sorcerer's defense value will decrease by the the attack value of player's Wimp card. Therefore, after the attack, the defense value will change from 55 to 15, as 55 - 40 = 15. Therefore,
#
#         Opponent card
#
#         Name: Sorcerer
#         Health: 100
#         Attack: 70
#         Defense: 15
#
#         Now, if in the next round, Wimp attacks Sorcerer again, then Sorcerer's defense value will decrease to 0, but its health will also be affected. The health will be affected by 25 points, as 40 - 15 = 25. So, Sorcerer's health will now decrease from 100 to 75
#
#         Opponent card
#
#         Name: Sorcerer
#         Health: 75
#         Attack: 70
#         Defense: 0
#
#         Now, let's say in a later round, the player uses the Marauder card, which has an attack value of 85, and the computer is using Sorcerer, whose health value is 75.
#
#         In that case, Sorcerer will be defeated, as 85 > 75. When this happens, remove the Sorcerer card from the deck of the opponent.
#
#         Display properly all these changes to the player at every round, so that they know how their attacks affected the round and what they can do next.
#
#         DO NOT just show the card details. Write proper statements, describing the process, as you may have seen in the demonstration given by the teacher
#
#         4.5.2. After the user's turn, make sure all the card values adjusted accordingly, just as described above.
#         4.5.3. ONLY a card's 'Defense' and 'Health' value changes after an attack. And once the 'Health' value of a card reaches 0 or drops below it, that card MUST be removed from the deck.
#         4.5.4. After the player's turn, pause the second for some seconds, e.g., time.sleep(3) will pause the game for 3 seconds.
#     4.6. Display that now it's the opponent's turn.
#     4.7. Make sure there are cards available in opponent's deck. If there aren't, then the game ends and the player wins.
#     4.8. If there are still cards available in opponent's deck, draw a random card from the opponent's deck, and display its details to the player.
#     4.9. Then display the cards available in the player's deck.
#     4.10 Ask the user to pick one card from their own deck to fight the opponent's card.
#     4.11. REPEAT THE SAME LOGIC AS STATED FROM POINT 4.4 TO 4.5.3. But this time, from the perspective of the opponent.
#     4.12. After the opponent's turn is over, display that a new round will begin in some seconds.
# 5. If it's found that the opponent has no card in their deck, then display a message stating player is the winner, otherwise display that the opponent won.

# %%
import random
import time

# Define the attributes for the cards
Name_list = ["Diablo", "Medusa", "Jester", "Troll", "Specter", "Mist", "Savage", "Marauder", "Wimp", "Sorcerer"]
Health_list = [100, 100, 120, 150, 100, 100, 100, 100, 110, 100]
Attack_list = [90, 70, 60, 40, 70, 75, 90, 85, 40, 70]
Defense_list = [60, 70, 90, 94, 70, 65, 50, 50, 85, 55]

# Zipping the lists into card_deck
card_deck = list(zip(Name_list, Health_list, Attack_list, Defense_list))

# Shuffle the deck
random.shuffle(card_deck)

# Split the deck between player and opponent
deck_size = 5
player_deck = card_deck[:deck_size]
opponent_deck = card_deck[deck_size:deck_size*2]

# Initialize game state variables
selected_player_card_index = None
player_deck_size = deck_size
opponent_deck_size = deck_size
game_over = False

def display_card(card):
    if card is None:
        return "Empty"
    name, health, attack, defense = card
    return f"{name}: Health: {health}, Attack: {attack}, Defense: {defense}"

def attack_card(attacker, defender):
    if attacker is None or defender is None:
        return defender

    defender_name, defender_health, defender_attack, defender_defense = defender
    attacker_name, attacker_health, attacker_attack, attacker_defense = attacker

    if defender_defense > 0:
        if defender_defense >= attacker_attack:
            defender_defense -= attacker_attack
        else:
            remaining_attack = attacker_attack - defender_defense
            defender_defense = 0
            defender_health -= remaining_attack
    else:
        defender_health -= attacker_attack

    return defender_name, defender_health, defender_attack, defender_defense

def print_decks():
    print("\nYour deck:")
    for i, card in enumerate(player_deck):
        print(f"{i+1}. {display_card(card)}")
    print("\nOpponent's deck:")
    for i, card in enumerate(opponent_deck):
        print(f"{i+1}. {display_card(card)}")

def select_player_card():
    global selected_player_card_index
    while selected_player_card_index is None:
        try:
            print("\nSelect a card to attack (1-5): ")
            selected_player_card_index = int(input()) - 1
            if selected_player_card_index < 0 or selected_player_card_index >= len(player_deck) or player_deck[selected_player_card_index] is None:
                print("Invalid selection or card already defeated. Try again.")
                selected_player_card_index = None
        except ValueError:
            print("Invalid input. Please enter a number between 1 and 5.")

def select_opponent_card():
    global selected_player_card_index
    while selected_player_card_index is not None:
        try:
            print("\nSelect an opponent card to attack (1-5): ")
            opponent_card_index = int(input()) - 1
            if opponent_card_index < 0 or opponent_card_index >= len(opponent_deck) or opponent_deck[opponent_card_index] is None:
                print("Invalid selection or card already defeated. Try again.")
            else:
                player_card = player_deck[selected_player_card_index]
                opponent_card = opponent_deck[opponent_card_index]
                updated_opponent_card = attack_card(player_card, opponent_card)
                opponent_deck[opponent_card_index] = updated_opponent_card

                if updated_opponent_card[1] <= 0:
                    print(f"\nYou defeated {updated_opponent_card[0]}!")
                    opponent_deck[opponent_card_index] = None
                else:
                    print(f"\nAfter your attack: {display_card(updated_opponent_card)}")

                selected_player_card_index = None
                check_game_over()
                if not game_over:
                    opponent_attack()
        except ValueError:
            print("Invalid input. Please enter a number between 1 and 5.")

def opponent_attack():
    global player_deck, opponent_deck
    if not player_deck or not opponent_deck:
        return

    opponent_card = random.choice([card for card in opponent_deck if card is not None])
    player_card = random.choice([card for card in player_deck if card is not None])

    updated_player_card = attack_card(opponent_card, player_card)
    player_deck[player_deck.index(player_card)] = updated_player_card

    if updated_player_card[1] <= 0:
        print(f"\nOpponent defeated your {updated_player_card[0]}!")
        player_deck[player_deck.index(updated_player_card)] = None

    print(f"\nAfter opponent's attack: {display_card(updated_player_card)}")
    check_game_over()

def check_game_over():
    global game_over

    player_defeated = sum(1 for card in player_deck if card is None)
    opponent_defeated = sum(1 for card in opponent_deck if card is None)

    if player_defeated >= player_deck_size:
        if not game_over:  
            print("You lost all your cards! Game Over!")
            game_over = True
        return True
    elif opponent_defeated >= opponent_deck_size:
        if not game_over:  
            print("You defeated all opponent cards! Victory!")
            game_over = True
        return True
    return False

# Game loop
while not game_over:
    print_decks()
    select_player_card()
    select_opponent_card()
# Out:
# Your deck:
# 1. Troll: Health: 150, Attack: 40, Defense: 94
# 2. Marauder: Health: 100, Attack: 85, Defense: 50
# 3. Savage: Health: 100, Attack: 90, Defense: 50
# 4. Sorcerer: Health: 100, Attack: 70, Defense: 55
# 5. Diablo: Health: 100, Attack: 90, Defense: 60
#
# Opponent's deck:
# 1. Medusa: Health: 100, Attack: 70, Defense: 70
# 2. Specter: Health: 100, Attack: 70, Defense: 70
# 3. Jester: Health: 120, Attack: 60, Defense: 90
# 4. Mist: Health: 100, Attack: 75, Defense: 65
# 5. Wimp: Health: 110, Attack: 40, Defense: 85
#
# Select a card to attack (1-5):
# Select an opponent card to attack (1-5):
#
# After your attack: Medusa: Health: 80, Attack: 70, Defense: 0
#
# After opponent's attack: Marauder: Health: 75, Attack: 85, Defense: 0
#
# Your deck:
# 1. Troll: Health: 150, Attack: 40, Defense: 94
# 2. Marauder: Health: 75, Attack: 85, Defense: 0
# 3. Savage: Health: 100, Attack: 90, Defense: 50
# 4. Sorcerer: Health: 100, Attack: 70, Defense: 55
# 5. Diablo: Health: 100, Attack: 90, Defense: 60
#
# Opponent's deck:
# 1. Medusa: Health: 80, Attack: 70, Defense: 0
# 2. Specter: Health: 100, Attack: 70, Defense: 70
# 3. Jester: Health: 120, Attack: 60, Defense: 90
# 4. Mist: Health: 100, Attack: 75, Defense: 65
# 5. Wimp: Health: 110, Attack: 40, Defense: 85
#
# Select a card to attack (1-5):
#
# Select an opponent card to attack (1-5):
#
# You defeated Medusa!
#
# After opponent's attack: Troll: Health: 150, Attack: 40, Defense: 24
#
# Your deck:
# 1. Troll: Health: 150, Attack: 40, Defense: 24
# 2. Marauder: Health: 75, Attack: 85, Defense: 0
# 3. Savage: Health: 100, Attack: 90, Defense: 50
# 4. Sorcerer: Health: 100, Attack: 70, Defense: 55
# 5. Diablo: Health: 100, Attack: 90, Defense: 60
#
# Opponent's deck:
# 1. Empty
# 2. Specter: Health: 100, Attack: 70, Defense: 70
# 3. Jester: Health: 120, Attack: 60, Defense: 90
# 4. Mist: Health: 100, Attack: 75, Defense: 65
# 5. Wimp: Health: 110, Attack: 40, Defense: 85
#
# Select a card to attack (1-5):
#
# Select an opponent card to attack (1-5):
# Invalid selection or card already defeated. Try again.
#
# Select an opponent card to attack (1-5):
#
# After your attack: Jester: Health: 120, Attack: 60, Defense: 0
#
# After opponent's attack: Troll: Health: 104, Attack: 40, Defense: 0
#
# Your deck:
# 1. Troll: Health: 104, Attack: 40, Defense: 0
# 2. Marauder: Health: 75, Attack: 85, Defense: 0
# 3. Savage: Health: 100, Attack: 90, Defense: 50
# 4. Sorcerer: Health: 100, Attack: 70, Defense: 55
# 5. Diablo: Health: 100, Attack: 90, Defense: 60
#
# Opponent's deck:
# 1. Empty
# 2. Specter: Health: 100, Attack: 70, Defense: 70
# 3. Jester: Health: 120, Attack: 60, Defense: 0
# 4. Mist: Health: 100, Attack: 75, Defense: 65
# 5. Wimp: Health: 110, Attack: 40, Defense: 85
#
# Select a card to attack (1-5):
#
# Select an opponent card to attack (1-5):
#
# After your attack: Jester: Health: 50, Attack: 60, Defense: 0
#
# After opponent's attack: Marauder: Health: 5, Attack: 85, Defense: 0
#
# Your deck:
# 1. Troll: Health: 104, Attack: 40, Defense: 0
# 2. Marauder: Health: 5, Attack: 85, Defense: 0
# 3. Savage: Health: 100, Attack: 90, Defense: 50
# 4. Sorcerer: Health: 100, Attack: 70, Defense: 55
# 5. Diablo: Health: 100, Attack: 90, Defense: 60
#
# Opponent's deck:
# 1. Empty
# 2. Specter: Health: 100, Attack: 70, Defense: 70
# 3. Jester: Health: 50, Attack: 60, Defense: 0
# 4. Mist: Health: 100, Attack: 75, Defense: 65
# 5. Wimp: Health: 110, Attack: 40, Defense: 85
#
# Select a card to attack (1-5):
#
# Select an opponent card to attack (1-5):
#
# You defeated Jester!
#
# After opponent's attack: Troll: Health: 29, Attack: 40, Defense: 0
#
# Your deck:
# 1. Troll: Health: 29, Attack: 40, Defense: 0
# 2. Marauder: Health: 5, Attack: 85, Defense: 0
# 3. Savage: Health: 100, Attack: 90, Defense: 50
# 4. Sorcerer: Health: 100, Attack: 70, Defense: 55
# 5. Diablo: Health: 100, Attack: 90, Defense: 60
#
# Opponent's deck:
# 1. Empty
# 2. Specter: Health: 100, Attack: 70, Defense: 70
# 3. Empty
# 4. Mist: Health: 100, Attack: 75, Defense: 65
# 5. Wimp: Health: 110, Attack: 40, Defense: 85
#
# Select a card to attack (1-5):
#
# Select an opponent card to attack (1-5):
# Invalid selection or card already defeated. Try again.
#
# Select an opponent card to attack (1-5):
# Invalid selection or card already defeated. Try again.
#
# Select an opponent card to attack (1-5):
# Invalid selection or card already defeated. Try again.
#
# Select an opponent card to attack (1-5):
# Invalid selection or card already defeated. Try again.
#
# Select an opponent card to attack (1-5):
# Invalid selection or card already defeated. Try again.
#
# Select an opponent card to attack (1-5):
# Invalid selection or card already defeated. Try again.
#
# Select an opponent card to attack (1-5):
# Invalid selection or card already defeated. Try again.
#
# Select an opponent card to attack (1-5):
#
# After your attack: Specter: Health: 100, Attack: 70, Defense: 0
#
# After opponent's attack: Diablo: Health: 100, Attack: 90, Defense: 20
#
# Your deck:
# 1. Troll: Health: 29, Attack: 40, Defense: 0
# 2. Marauder: Health: 5, Attack: 85, Defense: 0
# 3. Savage: Health: 100, Attack: 90, Defense: 50
# 4. Sorcerer: Health: 100, Attack: 70, Defense: 55
# 5. Diablo: Health: 100, Attack: 90, Defense: 20
#
# Opponent's deck:
# 1. Empty
# 2. Specter: Health: 100, Attack: 70, Defense: 0
# 3. Empty
# 4. Mist: Health: 100, Attack: 75, Defense: 65
# 5. Wimp: Health: 110, Attack: 40, Defense: 85
#
# Select a card to attack (1-5):
#
# Select an opponent card to attack (1-5):
#
# After your attack: Specter: Health: 10, Attack: 70, Defense: 0
#
# After opponent's attack: Savage: Health: 100, Attack: 90, Defense: 10
#
# Your deck:
# 1. Troll: Health: 29, Attack: 40, Defense: 0
# 2. Marauder: Health: 5, Attack: 85, Defense: 0
# 3. Savage: Health: 100, Attack: 90, Defense: 10
# 4. Sorcerer: Health: 100, Attack: 70, Defense: 55
# 5. Diablo: Health: 100, Attack: 90, Defense: 20
#
# Opponent's deck:
# 1. Empty
# 2. Specter: Health: 10, Attack: 70, Defense: 0
# 3. Empty
# 4. Mist: Health: 100, Attack: 75, Defense: 65
# 5. Wimp: Health: 110, Attack: 40, Defense: 85
#
# Select a card to attack (1-5):
#
# Select an opponent card to attack (1-5):
#
# You defeated Specter!
#
# After opponent's attack: Savage: Health: 35, Attack: 90, Defense: 0
#
# Your deck:
# 1. Troll: Health: 29, Attack: 40, Defense: 0
# 2. Marauder: Health: 5, Attack: 85, Defense: 0
# 3. Savage: Health: 35, Attack: 90, Defense: 0
# 4. Sorcerer: Health: 100, Attack: 70, Defense: 55
# 5. Diablo: Health: 100, Attack: 90, Defense: 20
#
# Opponent's deck:
# 1. Empty
# 2. Empty
# 3. Empty
# 4. Mist: Health: 100, Attack: 75, Defense: 65
# 5. Wimp: Health: 110, Attack: 40, Defense: 85
#
# Select a card to attack (1-5):
#
# Select an opponent card to attack (1-5):
# Invalid selection or card already defeated. Try again.
#
# Select an opponent card to attack (1-5):
# Invalid selection or card already defeated. Try again.
#
# Select an opponent card to attack (1-5):
#
# After your attack: Wimp: Health: 105, Attack: 40, Defense: 0
#
# After opponent's attack: Diablo: Health: 80, Attack: 90, Defense: 0
#
# Your deck:
# 1. Troll: Health: 29, Attack: 40, Defense: 0
# 2. Marauder: Health: 5, Attack: 85, Defense: 0
# 3. Savage: Health: 35, Attack: 90, Defense: 0
# 4. Sorcerer: Health: 100, Attack: 70, Defense: 55
# 5. Diablo: Health: 80, Attack: 90, Defense: 0
#
# Opponent's deck:
# 1. Empty
# 2. Empty
# 3. Empty
# 4. Mist: Health: 100, Attack: 75, Defense: 65
# 5. Wimp: Health: 105, Attack: 40, Defense: 0
#
# Select a card to attack (1-5):
#
# Select an opponent card to attack (1-5):
#
# After your attack: Wimp: Health: 20, Attack: 40, Defense: 0
#
# After opponent's attack: Sorcerer: Health: 100, Attack: 70, Defense: 15
#
# Your deck:
# 1. Troll: Health: 29, Attack: 40, Defense: 0
# 2. Marauder: Health: 5, Attack: 85, Defense: 0
# 3. Savage: Health: 35, Attack: 90, Defense: 0
# 4. Sorcerer: Health: 100, Attack: 70, Defense: 15
# 5. Diablo: Health: 80, Attack: 90, Defense: 0
#
# Opponent's deck:
# 1. Empty
# 2. Empty
# 3. Empty
# 4. Mist: Health: 100, Attack: 75, Defense: 65
# 5. Wimp: Health: 20, Attack: 40, Defense: 0
#
# Select a card to attack (1-5):
#
# Select an opponent card to attack (1-5):
#
# You defeated Wimp!
#
# Opponent defeated your Savage!
#
# After opponent's attack: Savage: Health: -40, Attack: 90, Defense: 0
#
# Your deck:
# 1. Troll: Health: 29, Attack: 40, Defense: 0
# 2. Marauder: Health: 5, Attack: 85, Defense: 0
# 3. Empty
# 4. Sorcerer: Health: 100, Attack: 70, Defense: 15
# 5. Diablo: Health: 80, Attack: 90, Defense: 0
#
# Opponent's deck:
# 1. Empty
# 2. Empty
# 3. Empty
# 4. Mist: Health: 100, Attack: 75, Defense: 65
# 5. Empty
#
# Select a card to attack (1-5):
#
# Select an opponent card to attack (1-5):
#
# After your attack: Mist: Health: 80, Attack: 75, Defense: 0
#
# After opponent's attack: Sorcerer: Health: 40, Attack: 70, Defense: 0
#
# Your deck:
# 1. Troll: Health: 29, Attack: 40, Defense: 0
# 2. Marauder: Health: 5, Attack: 85, Defense: 0
# 3. Empty
# 4. Sorcerer: Health: 40, Attack: 70, Defense: 0
# 5. Diablo: Health: 80, Attack: 90, Defense: 0
#
# Opponent's deck:
# 1. Empty
# 2. Empty
# 3. Empty
# 4. Mist: Health: 80, Attack: 75, Defense: 0
# 5. Empty
#
# Select a card to attack (1-5):
#
# Select an opponent card to attack (1-5):
#
# You defeated Mist!
# You defeated all opponent cards! Victory!
